# %% [markdown]
# Housing Statistics for Scotland - Public sector vacant stock

# %%
from gssutils import *

scraper = Scraper('https://www2.gov.scot/Topics/Statistics/Browse/Housing-Regeneration/HSfS/VacantStock')
scraper
# Out:
# ## Housing Statistics for Scotland - Public sector vacant stock
#
# ### Description
#
# Information on local authority owned vacant stock is collected form each local
# authority through the Housing Statistics Annual Return. Local authority
# dwellings can be vacant for a variety of reasons, such as being part of a
# planned disposal or modernisation/repair programme, or in low demand areas.
#
# Figures on vacant dwellings are broken down by reason for vacancy, and length
# of time the property has been vacant.
#
#
#
# ### Distributions
#
# 1. Local authority vacant stock by length of vacancy and reason for vacancy  ([MS Excel Spreadsheet](https://www2.gov.scot/Resource/0054/00540643.xls))

# %%
tabs = {tab.name: tab for tab in scraper.distribution().as_databaker()}
tabs.keys()
# Out:
# dict_keys(['DATA', 'NOTES', 'CONTENTS', 'tsAllVacant', 'tsTempHomeless', 'tsDemolish', 'tsModernise', 'tsLowDemand', 'tsOther', 'TblLASummary'])

# %%
tabs = scraper.distribution().as_databaker()

# %%
tenure = ['public-sector-vacant-stock',
          'public-sector-vacant-stock-used-as-temporary-accommodation-for-homeless',
          'public-sector-vacant-stock-awaiting-demolition',
          'public-sector-vacant-stock-forming-part-of-a-modernisation-scheme',
          'public-sector-vacant-stock-in-low-demand-areas',
          'public-sector-vacant-stock-other-types'
          ]

# %%
tidy = pd.DataFrame()
for i in range(3,9):
    print(i)
    tab = tabs[i]
    cell = tab.filter(contains_string('Public'))
    tl = cell.shift(0,1)
    area = tab.excel_ref('A1').expand(DOWN).is_not_blank().is_not_whitespace() -cell - tl
    year = tl.shift(0,1).fill(RIGHT).is_not_blank().is_not_whitespace()
    observations = area.fill(RIGHT).is_not_blank().is_not_whitespace()
    Dimensions = [
                HDim(year,'Year',DIRECTLY,ABOVE),
                HDim(tl,'Vacancy length',CLOSEST,ABOVE),
                HDim(area,'Area',DIRECTLY,LEFT),
                HDimConst('Measure Type', 'Count'),
                HDimConst('Unit', 'dwellings')
                ]
    c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)    
    table = c1.topandas()
    table['Tenure'] = tenure[i-3]
    tidy = pd.concat([tidy , table])
# Out:
# 3
#
# 4
#
# 5
#
# 6
#
# 7
#
# 8

# %%
import numpy as np
tidy['OBS'].replace('', np.nan, inplace=True)
tidy.dropna(subset=['OBS'], inplace=True)
if 'DATAMARKER' in tidy.columns:
    tidy.drop(columns=['DATAMARKER'], inplace=True)
tidy.rename(columns={'OBS': 'Value', 'Area':'Geography' }, inplace=True)
tidy['Value'] = tidy['Value'].astype(int)

# %%
tidy.rename(columns={'Year': 'Period'}, inplace=True)
tidy = tidy[tidy['Period'] != '']

# %%
tidy['Period'] = 'day/' + tidy['Period'].astype(str).str[:4] + '-03-31'

# %%
tidy['Vacancy length'] = tidy['Vacancy length'].map(
    lambda x: {
        'all vacant stock' : 'total', 'vacant for under 2 weeks' : 'under-2-weeks',
       'vacant for 2 to 6 weeks' : '2-to-6-weeks', 'vacant for 6 to 26 weeks' : '6-to-26-weeks',
       'vacant for 26 weeks to 2 years' : '26-weeks-to-2-years', 
        'vacant for longer than 2 years' : 'longer-than-2-years',
       'length of vacancy unknown' : 'unknown',
       'all vacant stock used as temporary accommodation for homeless' : 'total',
       'all vacant stock awaiting demolition' : 'total',
       'all vacant stock forming part of a modernisation scheme' :'total',
       'all vacant stock in low demand areas' : 'total',
       'all vacant stock of other types' : 'total'
        }.get(x, x))

# %%
tidy = tidy[tidy['Geography'] != 'Local Authorities']
tidy = tidy[tidy['Geography'] != 'Scottish Homes']

# %%
tidy['Geography'] = tidy['Geography'].map(
    lambda x: {
        'Scottish Borders, The' : 'Scottish Borders', 
        'Shetland' : 'Shetland Islands',
        'Na h-Eilanan Siar' : 'Na h-Eileanan Siar',
        'Orkney' : 'Orkney Islands'
        }.get(x, x))

# %%
scotland_gss_codes = pd.read_csv('scotland-gss.csv', index_col='Area')
tidy['Geography'] = tidy['Geography'].map(
    lambda x: scotland_gss_codes.loc[x]['Code']
)

# %%
tidy = tidy[['Period','Geography','Vacancy length','Tenure','Measure Type','Value','Unit']]

# %%
out = Path('out')
out.mkdir(exist_ok=True)
tidy.to_csv(out / 'observations.csv', index = False)

# %%
scraper.dataset.family = 'housing'
scraper.dataset.theme = THEME['housing-planning-local-services']
with open(out / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())
    
schema = CSVWSchema('https://ons-opendata.github.io/ref_housing/')
schema.create(out / 'observations.csv', out / 'observations.csv-schema.json')

# %%
tidy
# Out:
#               Period  Geography Vacancy length  \
# 0     day/1998-03-31  S92000003          total
# 1     day/1999-03-31  S92000003          total
# 2     day/2000-03-31  S92000003          total
# 3     day/2001-03-31  S92000003          total
# 4     day/2002-03-31  S92000003          total
# 5     day/2003-03-31  S92000003          total
# 6     day/2004-03-31  S92000003          total
# 7     day/2005-03-31  S92000003          total
# 8     day/2006-03-31  S92000003          total
# 9     day/2007-03-31  S92000003          total
# 10    day/2008-03-31  S92000003          total
# 11    day/2009-03-31  S92000003          total
# 12    day/2010-03-31  S92000003          total
# 13    day/2011-03-31  S92000003          total
# 14    day/2012-03-31  S92000003          total
# 15    day/2013-03-31  S92000003          total
# 16    day/2014-03-31  S92000003          total
# 17    day/2015-03-31  S92000003          total
# 18    day/2016-03-31  S92000003          total
# 19    day/2017-03-31  S92000003          total
# 20    day/2018-03-31  S92000003          total
# 42    day/1998-03-31  S12000033          total
# 43    day/1999-03-31  S12000033          total
# 44    day/2000-03-31  S12000033          total
# 45    day/2001-03-31  S12000033          total
# 46    day/2002-03-31  S12000033          total
# 47    day/2003-03-31  S12000033          total
# 48    day/2004-03-31  S12000033          total
# 49    day/2005-03-31  S12000033          total
# 50    day/2006-03-31  S12000033          total
# ...              ...        ...            ...
# 5094  day/2010-03-31  S12000039        unknown
# 5095  day/2011-03-31  S12000039        unknown
# 5096  day/2012-03-31  S12000039        unknown
# 5097  day/2013-03-31  S12000039        unknown
# 5098  day/2014-03-31  S12000039        unknown
# 5099  day/2015-03-31  S12000039        unknown
# 5100  day/2016-03-31  S12000039        unknown
# 5101  day/2017-03-31  S12000039        unknown
# 5102  day/2018-03-31  S12000039        unknown
# 5103  day/1998-03-31  S12000040        unknown
# 5104  day/1999-03-31  S12000040        unknown
# 5105  day/2000-03-31  S12000040        unknown
# 5106  day/2001-03-31  S12000040        unknown
# 5107  day/2002-03-31  S12000040        unknown
# 5108  day/2003-03-31  S12000040        unknown
# 5109  day/2004-03-31  S12000040        unknown
# 5110  day/2005-03-31  S12000040        unknown
# 5111  day/2006-03-31  S12000040        unknown
# 5112  day/2007-03-31  S12000040        unknown
# 5113  day/2008-03-31  S12000040        unknown
# 5114  day/2009-03-31  S12000040        unknown
# 5115  day/2010-03-31  S12000040        unknown
# 5116  day/2011-03-31  S12000040        unknown
# 5117  day/2012-03-31  S12000040        unknown
# 5118  day/2013-03-31  S12000040        unknown
# 5119  day/2014-03-31  S12000040        unknown
# 5120  day/2015-03-31  S12000040        unknown
# 5121  day/2016-03-31  S12000040        unknown
# 5122  day/2017-03-31  S12000040        unknown
# 5123  day/2018-03-31  S12000040        unknown
#
#                                       Tenure Measure Type  Value       Unit
# 0                 public-sector-vacant-stock        Count  18117  dwellings
# 1                 public-sector-vacant-stock        Count  19843  dwellings
# 2                 public-sector-vacant-stock        Count  21530  dwellings
# 3                 public-sector-vacant-stock        Count  22062  dwellings
# 4                 public-sector-vacant-stock        Count  20746  dwellings
# 5                 public-sector-vacant-stock        Count  16474  dwellings
# 6                 public-sector-vacant-stock        Count  14399  dwellings
# 7                 public-sector-vacant-stock        Count  14050  dwellings
# 8                 public-sector-vacant-stock        Count  12060  dwellings
# 9                 public-sector-vacant-stock        Count  10289  dwellings
# 10                public-sector-vacant-stock        Count   9269  dwellings
# 11                public-sector-vacant-stock        Count   9120  dwellings
# 12                public-sector-vacant-stock        Count   9756  dwellings
# 13                public-sector-vacant-stock        Count   7667  dwellings
# 14                public-sector-vacant-stock        Count   7847  dwellings
# 15                public-sector-vacant-stock        Count   7013  dwellings
# 16                public-sector-vacant-stock        Count   6556  dwellings
# 17                public-sector-vacant-stock        Count   6515  dwellings
# 18                public-sector-vacant-stock        Count   6181  dwellings
# 19                public-sector-vacant-stock        Count   6164  dwellings
# 20                public-sector-vacant-stock        Count   7140  dwellings
# 42                public-sector-vacant-stock        Count    838  dwellings
# 43                public-sector-vacant-stock        Count    962  dwellings
# 44                public-sector-vacant-stock        Count    967  dwellings
# 45                public-sector-vacant-stock        Count   1370  dwellings
# 46                public-sector-vacant-stock        Count   1257  dwellings
# 47                public-sector-vacant-stock        Count   1313  dwellings
# 48                public-sector-vacant-stock        Count   1388  dwellings
# 49                public-sector-vacant-stock        Count   1662  dwellings
# 50                public-sector-vacant-stock        Count   1371  dwellings
# ...                                      ...          ...    ...        ...
# 5094  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5095  public-sector-vacant-stock-other-types        Count     39  dwellings
# 5096  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5097  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5098  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5099  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5100  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5101  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5102  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5103  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5104  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5105  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5106  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5107  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5108  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5109  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5110  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5111  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5112  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5113  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5114  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5115  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5116  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5117  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5118  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5119  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5120  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5121  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5122  public-sector-vacant-stock-other-types        Count      0  dwellings
# 5123  public-sector-vacant-stock-other-types        Count      0  dwellings
#
# [24937 rows x 7 columns]
